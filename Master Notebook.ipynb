# %% [markdown]
# ## Master Notebook

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
#Load CHAS data
file = 'Datasets/CHAS.csv'
df_CHAS = pd.read_csv(file)
df_CHAS.head()
# Out:
#    OBJECTID  GEOID  STATE  COUNTY     NAME  T2_EST1  T8_EST69  T8_EST82  \
# 0         1   1043      1      43  Cullman    31735      1630      1605
# 1         2   1045      1      45     Dale    19405      1605      1760
# 2         3   1047      1      47   Dallas    15410      2455      1485
# 3         4   1049      1      49   DeKalb    26365      1810      1660
# 4         5   1051      1      51   Elmore    29795      1510      1880
#
#    T8_EST95  T8_EST108  ...  LF_LI_CB50_R  LF_MI_CB50_R  SF_ELI_CB50_O  \
# 0      1810        640  ...             0             0            190
# 1      1530        700  ...            20            10             60
# 2       930        790  ...            30             0             55
# 3      1570        580  ...             4             0            205
# 4      1350        855  ...             0             0            155
#
#    SF_LI_CB50_O  SF_MI_CB50_O  LF_ELI_CB50_O  LF_LI_CB50_O  LF_MI_CB50_O  \
# 0            80            50             10            10            10
# 1            15            20             10            10             0
# 2            55             0              0             0             0
# 3            70            25              4            45             4
# 4            30           210              0            15             0
#
#     Shape__Area  Shape__Length
# 0  2.861199e+09  295392.576915
# 1  2.007843e+09  200998.041741
# 2  3.615258e+09  375473.625434
# 3  2.973710e+09  274855.473716
# 4  2.404341e+09  273321.812364
#
# [5 rows x 408 columns]

# %%
#Load demographic data
file = 'Datasets/Demographic.csv'
df_Demo = pd.read_csv(file)
df_Demo.head()
# Out:
#    OBJECTID_1  OBJECTID  GEOID  STATE STUSAB STATE_NAME  COUNTY          NAME  \
# 0           1         0   2020      2     AK     Alaska      20     Anchorage
# 1           2         0   2050      2     AK     Alaska      50        Bethel
# 2           3         0   2060      2     AK     Alaska      60   Bristol Bay
# 3           4         0   2063      2     AK     Alaska      63       Chugach
# 4           5         0   2066      2     AK     Alaska      66  Copper River
#
#    B03002EST1  B01001_UNDER17  ...  CND_65UP  CND_65UP_PCT  AD_65UP  \
# 0      292090           70908  ...      7294         22.53     2169
# 1       18263            6508  ...       169         12.53       29
# 2         739             143  ...        20         23.26        4
# 3        6495            1387  ...       434         49.77       94
# 4        2894             805  ...        52         14.61        3
#
#    AD_65UP_PCT  BD_65UP  BD_65UP_PCT  GD_65UP  GD_65UP_PCT   Shape__Area  \
# 0         6.70     6055        18.70     6084        18.79  1.923023e+10
# 1         2.15       63         4.67      110         8.15  4.562014e+11
# 2         4.65       11        12.79        2         2.33  4.921460e+09
# 3        10.78      148        16.97       45         5.16  1.048120e+11
# 4         0.84      118        33.15       73        20.51  2.925218e+11
#
#    Shape__Length
# 0   7.368591e+05
# 1   9.237934e+06
# 2   3.368155e+05
# 3   1.135352e+07
# 4   3.013518e+06
#
# [5 rows x 124 columns]

# %%
#Load housing data
file = 'Datasets/Housing.csv'
df_Housing = pd.read_csv(file)
df_Housing.head()
# Out:
#    OBJECTID_1  GEOID  STATE STUSAB STATE_NAME  COUNTY                  NAME  \
# 0           1   2063      2     AK     Alaska      63               Chugach
# 1           2   2066      2     AK     Alaska      66          Copper River
# 2           3   2068      2     AK     Alaska      68                Denali
# 3           4   2070      2     AK     Alaska      70            Dillingham
# 4           5   2090      2     AK     Alaska      90  Fairbanks North Star
#
#    B25002EST1  B25002EST2  B25002EST2_PCT  ...  B25123EST10  B25123EST10_PCT  \
# 0        3287        2310           70.28  ...           45             7.26
# 1        2902        1063           36.63  ...           11             4.30
# 2        1664         726           43.63  ...           22            17.74
# 3        2462        1430           58.08  ...           51             9.01
# 4       44270       36199           81.77  ...          845             5.68
#
#    B25123EST11  B25123EST11_PCT  B25123EST12  B25123EST12_PCT  B25123EST13  \
# 0            1             0.16            0             0.00          362
# 1            6             2.34            0             0.00          166
# 2            0             0.00            7             5.65           40
# 3            8             1.41            0             0.00          287
# 4          528             3.55           16             0.11         7401
#
#    B25123EST13_PCT   Shape__Area  Shape__Length
# 0            58.39  1.048120e+11   1.135352e+07
# 1            64.84  2.925218e+11   3.013518e+06
# 2            32.26  1.661374e+11   2.084188e+06
# 3            50.71  1.934547e+11   3.421842e+06
# 4            49.72  1.058398e+11   1.883222e+06
#
# [5 rows x 245 columns]

# %%
#Load socioeconomic data
file = 'Datasets/Socioeconomic.csv'
df_Socioeconomic = pd.read_csv(file)
df_Socioeconomic.head()
# Out:
#    OBJECTID_1  GEOID  STATE STATE_NAME  COUNTY                  NAME  \
# 0           1   2066      2     Alaska      66          Copper River
# 1           2   2068      2     Alaska      68                Denali
# 2           3   2070      2     Alaska      70            Dillingham
# 3           4   2090      2     Alaska      90  Fairbanks North Star
# 4           5   2100      2     Alaska     100                Haines
#
#    B08013EST1  B08013_AVG_TTW  B08303EST1  B08303_30MINUS_TTW  ...  \
# 0     24535.0           24.39        1006                 866  ...
# 1     26985.0           16.31        1654                1394  ...
# 2     15095.0            8.74        1728                1636  ...
# 3    912910.0           19.12       47758               38747  ...
# 4      7055.0            9.46         746                 698  ...
#
#    B23006EST29  B23006EST29_PCT  B24021EST2  B24021EST17  B24021EST25  \
# 0           59            12.88     78472.0          NaN      36250.0
# 1           46            25.41     70179.0          NaN       8884.0
# 2           24             3.82     56136.0      82679.0      68125.0
# 3         2498            23.55     72774.0      65298.0      31759.0
# 4           51            33.55     64141.0          NaN          NaN
#
#    B24021EST28  B24021EST29  B24021EST32   Shape__Area  Shape__Length
# 0      61042.0      76250.0      80313.0  2.925218e+11   3.013518e+06
# 1      13573.0      90938.0     107344.0  1.661374e+11   2.084188e+06
# 2      42132.0      56036.0      47188.0  1.934547e+11   3.421842e+06
# 3      47667.0      64513.0      61458.0  1.058398e+11   1.883222e+06
# 4      63125.0      22115.0      20705.0  2.336479e+10   1.866179e+06
#
# [5 rows x 146 columns]

# %%
file = 'Datasets/regression_data_final.csv'
df_master = pd.read_csv(file)
df_master
# Out:
#       LESSTHAN80  LTHS_25TO34_PCT  TOT_POP  TOT_HOUSING_UNITS  UNEMPLRT  \
# 0          13230             2.34    83345              38056      5.01
# 1           8435             1.88    49293              23151      9.02
# 2           8215             3.43    38184              20427     10.38
# 3          12320             8.65    71430              31424      4.45
# 4          10575             3.39    81526              34332      4.07
# ...          ...              ...      ...                ...       ...
# 1879      101200             3.27  1149439             415149      4.05
# 1880       25990             2.85   135169              60145      6.12
# 1881        8280             5.78    53558              18317      4.74
# 1882        6145             2.23    22500              10354      8.41
# 1883       13540             3.09    80970              32533      6.31
#
#       POVRT  PASSED_THRESHOLD  CDBG_PER_PR_RESID
# 0     12.69                 0          57.568307
# 1     18.38                 0          39.066271
# 2     29.22                 0          27.828899
# 3     20.71                 0          48.009318
# 4     10.58                 0          96.182794
# ...     ...               ...                ...
# 1879   5.89                 0         164.231079
# 1880  15.29                 0         110.411424
# 1881  25.55                 0          33.040186
# 1882  24.70                 0         124.343061
# 1883  17.08                 0         175.442016
#
# [1884 rows x 8 columns]
