# %% [markdown]
# ## Master Notebook

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Main Files

# %% [markdown]
# ### CHAS

# %% [markdown]
# [CHAS Summary Website](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::acs-5yr-chas-estimate-data-by-county/about)

# %%
#Load CHAS data
file = 'Datasets/CHAS.csv'
df_CHAS = pd.read_csv(file)
show(df_CHAS)
# Out:
# <table id="itables_e39f1272_e73b_4141_840d_97a43356a265" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>OBJECTID</th>
#       <th>GEOID</th>
#       <th>STATE</th>
#       <th>COUNTY</th>
#       <th>NAME</th>
#       <th>T2_EST1</th>
#       <th>T8_EST69</th>
#       <th>T8_EST82</th>
#       <th>T8_EST95</th>
#       <th>T8_EST108</th>
#       <th>T8_EST68</th>
#       <th>T8_EST3</th>
#       <th>T8_EST16</th>
#       <th>T8_EST29</th>
#       <th>T8_EST42</th>
#       <th>T8_EST2</th>
#       <th>T3_EST47</th>
#       <th>T3_EST48</th>
#       <th>T3_EST49</th>
#       <th>T3_EST50</th>
#       <th>T3_EST46</th>
#       <th>T3_EST4</th>
#       <th>T3_EST5</th>
#       <th>T3_EST6</th>
#       <th>T3_EST7</th>
#       <th>T3_EST3</th>
#       <th>T3_EST53</th>
#       <th>T3_EST54</th>
#       <th>T3_EST55</th>
# ...

# %% [markdown]
# ### Demographic

# %% [markdown]
# [Demographic Summary Website](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::acs-5yr-demographic-estimate-data-by-county/about)

# %%
#Load demographic data
file = 'Datasets/Demographic.csv'
df_Demo = pd.read_csv(file)
show(df_Demo)
# Out:
# <table id="itables_c462b1a6_ca1f_4979_976b_e3fc4b46e3c3" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>OBJECTID_1</th>
#       <th>OBJECTID</th>
#       <th>GEOID</th>
#       <th>STATE</th>
#       <th>STUSAB</th>
#       <th>STATE_NAME</th>
#       <th>COUNTY</th>
#       <th>NAME</th>
#       <th>B03002EST1</th>
#       <th>B01001_UNDER17</th>
#       <th>B01001_UNDER17_PCT</th>
#       <th>B01001_18TO24</th>
#       <th>B01001_18TO24_PCT</th>
#       <th>B01001_25TO64</th>
#       <th>B01001_25TO64_PCT</th>
#       <th>B01001_ABOVE64</th>
#       <th>B01001_ABOVE64_PCT</th>
#       <th>B03002EST3</th>
#       <th>B03002EST3_PCT</th>
#       <th>B03002EST4</th>
#       <th>B03002EST4_PCT</th>
#       <th>B03002EST5</th>
#       <th>B03002EST5_PCT</th>
#       <th>B03002EST6</th>
#       <th>B03002EST6_PCT</th>
# ...

# %% [markdown]
# ### Housing

# %% [markdown]
# [Housing Summary Website](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::acs-5yr-housing-estimate-data-by-county/about)

# %%
#Load housing data
file = 'Datasets/Housing.csv'
df_Housing = pd.read_csv(file)
show(df_Housing)
# Out:
# <table id="itables_b8365bbe_b293_4121_9452_c69feee754e5" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>OBJECTID_1</th>
#       <th>GEOID</th>
#       <th>STATE</th>
#       <th>STUSAB</th>
#       <th>STATE_NAME</th>
#       <th>COUNTY</th>
#       <th>NAME</th>
#       <th>B25002EST1</th>
#       <th>B25002EST2</th>
#       <th>B25002EST2_PCT</th>
#       <th>B25002EST3</th>
#       <th>B25002EST3_PCT</th>
#       <th>B25009EST2</th>
#       <th>B25009EST2_PCT</th>
#       <th>B25009EST3</th>
#       <th>B25009EST3_PCT</th>
#       <th>B25009EST4</th>
#       <th>B25009EST4_PCT</th>
#       <th>B25009EST5</th>
#       <th>B25009EST5_PCT</th>
#       <th>B25009EST6</th>
#       <th>B25009EST6_PCT</th>
#       <th>B25009EST7</th>
#       <th>B25009EST7_PCT</th>
#       <th>B25009_OWNOCC_6PLUS</th>
#       <th>B25009_OWN_6PLUS_PCT</th>
# ...

# %% [markdown]
# ### Socioeconomic

# %% [markdown]
# [Socioeconomic Summary Website](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::acs-5yr-socioeconomic-estimate-data-by-county/about)

# %%
#Load socioeconomic data
file = 'Datasets/Socioeconomic.csv'
df_Socioeconomic = pd.read_csv(file)
show(df_Socioeconomic)
# Out:
# <table id="itables_31a5fe6b_6a4b_495e_ae55_ebd521617c74" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>OBJECTID_1</th>
#       <th>GEOID</th>
#       <th>STATE</th>
#       <th>STATE_NAME</th>
#       <th>COUNTY</th>
#       <th>NAME</th>
#       <th>B08013EST1</th>
#       <th>B08013_AVG_TTW</th>
#       <th>B08303EST1</th>
#       <th>B08303_30MINUS_TTW</th>
#       <th>B08303_30MINUS_TTW_PCT</th>
#       <th>B08303_30TO59_TTW</th>
#       <th>B08303_30TO59_TTW_PCT</th>
#       <th>B08303_60PLUS_TTW</th>
#       <th>B08303_60PLUS_TTW_PCT</th>
#       <th>B17019EST2</th>
#       <th>B17019_OWN</th>
#       <th>B17019_OWN_PCT</th>
#       <th>B17019_RENT</th>
#       <th>B17019_RENT_PCT</th>
#       <th>B17021EST1</th>
#       <th>B17021EST2</th>
#       <th>B17021EST2_PCT</th>
#       <th>B17021_FAM</th>
#       <th>B17021_FAM_PCT</th>
# ...

# %% [markdown]
# ### CDBG

# %% [markdown]
# [CDBG Summary Website](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::community-development-block-grant-activity/about)

# %%
file = 'Datasets/CDBG.csv'
df_CDBG = pd.read_csv(file)
show(df_CDBG)
# Out:
# <table id="itables_2197b94f_75a0_4d6a_844e_ffcc290c99fb" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>OBJECTID</th>
#       <th>ID</th>
#       <th>GRANTEE</th>
#       <th>GRANTEE_TYPE</th>
#       <th>GRANTEE_ID</th>
#       <th>IDIS_ACTV_ID</th>
#       <th>ADDRESS</th>
#       <th>CITY</th>
#       <th>STATE</th>
#       <th>ZIP</th>
#       <th>LAT</th>
#       <th>LON</th>
#       <th>GROUPING</th>
#       <th>NAME</th>
#       <th>ALIAS</th>
#       <th>ACTV_FUNDING_AMT</th>
#       <th>COMPLETED_DT</th>
#       <th>ID_CHAR</th>
#       <th>x</th>
#       <th>y</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# ...
